# %%
import pandas as pd
import geopandas

# %%
neighborhoods = pd.read_csv("Sex_occupation.csv")
#pd.read_csv("https://pittsburghpa.maps.arcgis.com/apps/OnePane/basicviewer/index.html?appid=061230fc878b4112a708eae8e3cd67e7")

# %%
neighborhoods.head(91)
# Out:
#            Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0      Allegheny Center   1             579.0               131.000000
# 1        Allegheny West   2             221.0                80.000000
# 2             Allentown   3             841.0               170.064694
# 3             Arlington   4             991.0               207.465660
# 4     Arlington Heights   5              80.0                57.000000
# ..                  ...  ..               ...                      ...
# 86  Upper Lawrenceville  87            1518.0               265.427956
# 87             West End  88             186.0               108.000000
# 88         West Oakland  89             656.0               203.273215
# 89             Westwood  90            1798.0               221.774660
# 90              Windgap  91             695.0               158.142341
#
#     Estimate; Male:  Margin of Error; Male:  \
# 0             377.0              112.000000
# ...

# %%
Pick nieghborhoods

List of occupations:

transportation
Medical
Business admin 
Science
Social Science
Legal

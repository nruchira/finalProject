# %% [markdown]
# # Crime in Each Neighborhood

# %% [markdown]
# insert little blurb about why this metric is important and indicative of "bestness"

# %% [markdown]
# Lets breakdown this data!
#
# count how many nieghborhoods the data has, filter the data to iinclude the relevant neighboorhoods, calculate number of crimes in each neighborhood, determine neighborhood with the least amount of crime.

# %%
import pandas as pd

raw_data = pd.read_csv("crime.csv",  index_col="_id")

data = raw_data.drop(columns=['X', 'Y', 'PUBLIC_WORKS_DIVISION', 'COUNCIL_DISTRICT', 'INCIDENTTRACT', 'OFFENSES', 'INCIDENTZONE', 'CLEAREDFLAG', 'INCIDENTTIME', 'HIERARCHY', 'CCR', 'PK'])
data.head(10)
# Out:
#                                   INCIDENTLOCATION  \
# _id
# 1    400 Block North Shore DR Pittsburgh, PA 15212
# 2      5400 Block Carnegie ST Pittsburgh, PA 15201
# 3    500 Block Mt Pleasant RD Pittsburgh, PA 15214
# 4           300 Block Wood ST Pittsburgh, PA 15222
# 5    500 Block Mt Pleasant RD Pittsburgh, PA 15214
# 6      1300 Block E CARSON ST Pittsburgh, PA 15203
# 7      1200 Block Lakewood ST Pittsburgh, PA 15220
# 8      1500 Block E Carson ST Pittsburgh, PA 15203
# 9         1200 Block Nolan CT Pittsburgh, PA 15221
# 10         2400 Block Berg ST Pittsburgh, PA 15203
#
#             INCIDENTNEIGHBORHOOD                     INCIDENTHIERARCHYDESC
# _id
# 1                    North Shore            HARRASSMENT/THREAT/ATTEMPT/PHY
# 2            Upper Lawrenceville                        THEFT BY DECEPTION
# 3              Northview Heights   DISCHARGE OF FIREARM INTO OCC.STRUCTURE
# 4    Golden Triangle/Civic Arena            HARRASSMENT/THREAT/ATTEMPT/PHY
# ...

# %%
#ndata = data.groupby("INCIDENTNEIGHBORHOOD").count()

#data['INCIDENTNEIGHBORHOOD'].value_counts()

#len(data['INCIDENTNEIGHBORHOOD'].unique())

data.groupby('INCIDENTNEIGHBORHOOD').count()
# Out:
#                        _id    PK   CCR  HIERARCHY  INCIDENTTIME  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center      3532  3532  3532       3532          3532
# Allegheny West        1077  1077  1077       1077          1077
# Allentown             5164  5164  5164       5164          5164
# Arlington             2109  2109  2109       2109          2109
# Arlington Heights      561   561   561        561           561
# ...                    ...   ...   ...        ...           ...
# Upper Lawrenceville   1635  1635  1635       1635          1635
# West End              1247  1247  1247       1247          1247
# West Oakland          1920  1920  1920       1920          1920
# Westwood              1606  1606  1606       1606          1606
# Windgap                872   872   872        872           872
#
#                       INCIDENTLOCATION  CLEAREDFLAG  INCIDENTZONE  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center                  3532         3532          3532
# ...
